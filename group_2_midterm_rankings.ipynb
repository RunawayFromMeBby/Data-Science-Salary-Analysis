# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("resources/data_cleaned_2021.csv")
df
# Out:
#      index                                          Job Title  \
# 0        0                                     Data Scientist
# 1        1                          Healthcare Data Scientist
# 2        2                                     Data Scientist
# 3        3                                     Data Scientist
# 4        4                                     Data Scientist
# ..     ...                                                ...
# 737    950           Sr Scientist, Immuno-Oncology - Oncology
# 738    951                               Senior Data Engineer
# 739    952  Project Scientist - Auton Lab, Robotics Institute
# 740    953                               Data Science Manager
# 741    955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# 738  $72K-$133K (Glassdoor est.)
# 739   $56K-$91K (Glassdoor est.)
# 740  $95K-$160K (Glassdoor est.)
# 741  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 737  Site Name: USA - Massachusetts - Cambridge\nPo...     3.9
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 741  Returning Candidate? Log back in to the Career...     3.6
#
#                                    Company Name         Location  \
# 0                        Tecolote Research\n3.8  Albuquerque, NM
# 1    University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                  KnowBe4\n4.8   Clearwater, FL
# 3                                     PNNL\n3.8     Richland, WA
# 4                       Affinity Solutions\n2.9     New York, NY
# ..                                          ...              ...
# 737                                    GSK\n3.9    Cambridge, MA
# 738                             Eventbrite\n4.4    Nashville, TN
# 739         Software Engineering Institute\n2.6   Pittsburgh, PA
# 740                           Numeric, LLC\n3.2    Allentown, PA
# 741           Riverside Research Institute\n3.6  Beavercreek, OH
#
#                   Headquarters          Size  Founded  ... tensor hadoop  \
# 0                   Goleta, CA   501 - 1000      1973  ...      0      0
# 1                Baltimore, MD       10000+      1984  ...      0      0
# 2               Clearwater, FL   501 - 1000      2010  ...      0      0
# 3                 Richland, WA  1001 - 5000      1965  ...      0      0
# 4                 New York, NY     51 - 200      1998  ...      0      0
# ..                         ...           ...      ...  ...    ...    ...
# 737  Brentford, United Kingdom       10000+      1830  ...      0      0
# 738          San Francisco, CA  1001 - 5000      2006  ...      0      1
# 739             Pittsburgh, PA   501 - 1000      1984  ...      0      0
# 740            Chadds Ford, PA       1 - 50        -1  ...      0      0
# 741              Arlington, VA   501 - 1000      1967  ...      0      0
#
#     tableau bi flink  mongo  google_an    job_title_sim  seniority_by_title  \
# 0         1  1     0      0          0   data scientist                  na
# 1         0  0     0      0          0   data scientist                  na
# 2         0  0     0      0          0   data scientist                  na
# 3         0  0     0      0          0   data scientist                  na
# 4         0  0     0      0          0   data scientist                  na
# ..      ... ..   ...    ...        ...              ...                 ...
# 737       0  0     0      0          0  other scientist                  sr
# 738       0  0     0      0          0    data engineer                  sr
# 739       0  0     0      0          0  other scientist                  na
# 740       0  0     0      0          0   data scientist                  na
# 741       0  0     0      0          0  other scientist                  na
#
#      Degree
# 0         M
# 1         M
# 2         M
# 3        na
# 4        na
# ..      ...
# 737       M
# 738      na
# 739       P
# 740      na
# 741       M
#
# [742 rows x 42 columns]

# %%
df.nlargest(10, 'Rating')
# Out:
#      index                                     Job Title  \
# 45      48                                Data Scientist
# 138    161                                 Data Engineer
# 373    477                                Data Scientist
# 424    542                                Data Scientist
# 693    893                         Senior Data Scientist
# 2        2                                Data Scientist
# 29      30                                Data Scientist
# 150    177                           Senior Data Analyst
# 208    255  Senior Research Statistician- Data Scientist
# 212    259                           Senior Data Analyst
#
#                           Salary Estimate  \
# 45   Employer Provided Salary:$150K-$160K
# 138  Employer Provided Salary:$120K-$145K
# 373  Employer Provided Salary:$150K-$160K
# 424           $75K-$127K (Glassdoor est.)
# 693  Employer Provided Salary:$120K-$140K
# 2              $80K-$90K (Glassdoor est.)
# 29             $80K-$90K (Glassdoor est.)
# 150            $44K-$78K (Glassdoor est.)
# 208           $76K-$125K (Glassdoor est.)
# 212            $44K-$78K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 45   BPA Services, LLC is seeking a Computer/Data S...     5.0
# 138  Location: Tampa, FL\nTitle: Data Engineer\nTS/...     5.0
# 373  BPA Services, LLC is seeking a Computer/Data S...     5.0
# 424  Title: Data Scientist\n\nLocation: Springfield...     5.0
# 693  SkySync is a dynamic, fast-paced, venture-back...     5.0
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 29   KnowBe4, Inc. is a high growth information sec...     4.8
# 150  KnowBe4, Inc. is a high growth information sec...     4.8
# 208  Acuity is seeking a Senior Research Statistici...     4.8
# 212  KnowBe4, Inc. is a high growth information sec...     4.8
#
#               Company Name         Location    Headquarters          Size  \
# 45       BPA Services\n5.0   Washington, DC  Alexandria, VA       unknown
# 138       Gridiron IT\n5.0        Tampa, FL      Reston, VA     51 - 200
# 373      BPA Services\n5.0   Washington, DC  Alexandria, VA       unknown
# 424  Royce Geospatial\n5.0  Springfield, VA   Arlington, VA     51 - 200
# 693           SkySync\n5.0    Ann Arbor, MI   Ann Arbor, MI     51 - 200
# 2             KnowBe4\n4.8   Clearwater, FL  Clearwater, FL   501 - 1000
# 29            KnowBe4\n4.8   Clearwater, FL  Clearwater, FL   501 - 1000
# 150           KnowBe4\n4.8   Clearwater, FL  Clearwater, FL   501 - 1000
# 208  Acuity Insurance\n4.8    Sheboygan, WI   Sheboygan, WI  1001 - 5000
# 212           KnowBe4\n4.8   Clearwater, FL  Clearwater, FL   501 - 1000
#
#      Founded  ... tensor hadoop tableau bi flink  mongo  google_an  \
# 45        -1  ...      0      0       0  0     0      0          0
# 138     2017  ...      0      0       0  0     0      0          0
# 373       -1  ...      0      0       0  0     0      0          0
# 424     2014  ...      0      0       0  0     0      0          0
# 693     2011  ...      0      0       0  0     0      0          0
# 2       2010  ...      0      0       0  0     0      0          0
# 29      2010  ...      0      0       0  0     0      0          0
# 150     2010  ...      0      0       0  0     0      0          0
# 208     1925  ...      0      0       0  0     0      0          0
# 212     2010  ...      0      0       0  0     0      0          0
#
#       job_title_sim  seniority_by_title  Degree
# 45   data scientist                  na      na
# 138   data engineer                  na      na
# 373  data scientist                  na      na
# 424  data scientist                  na      na
# 693  data scientist                  sr       M
# 2    data scientist                  na       M
# 29   data scientist                  na       M
# 150         analyst                  sr       M
# 208  data scientist                  sr       M
# 212         analyst                  sr       M
#
# [10 rows x 42 columns]

# %%
df.nsmallest(10, 'Rating')
# Out:
#      index                                          Job Title  \
# 176    208  Principal Data Scientist with over 10 years ex...
# 266    331  Principal Data Scientist with over 10 years ex...
# 300    377                               Data Operations Lead
# 370    472    Research Scientist, Immunology - Cancer Biology
# 404    518  Senior Scientist, Cell Pharmacology/Assay Deve...
# 456    583                                     Data Scientist
# 551    703    Research Scientist, Immunology - Cancer Biology
# 581    741      Scientist – Cancer Discovery, Molecular Assay
# 609    778  Senior Scientist, Cell Pharmacology/Assay Deve...
# 641    819  Principal Research Scientist/Team Lead, Medici...
#
#                           Salary Estimate  \
# 176  Employer Provided Salary:$200K-$250K
# 266  Employer Provided Salary:$200K-$250K
# 300    Employer Provided Salary:$85K-$90K
# 370  Employer Provided Salary:$100K-$140K
# 404  Employer Provided Salary:$110K-$130K
# 456           $81K-$140K (Glassdoor est.)
# 551  Employer Provided Salary:$100K-$140K
# 581  Employer Provided Salary:$100K-$135K
# 609  Employer Provided Salary:$110K-$130K
# 641  Employer Provided Salary:$120K-$145K
#
#                                        Job Description  Rating  \
# 176  Position Title: Principal Data Scientist\nLoca...    -1.0
# 266  Position Title: Principal Data Scientist\nLoca...    -1.0
# 300  Data Operations Lead\nLocation: Flexible thoug...    -1.0
# 370  Research Scientist, Immunology - Cancer Biolog...    -1.0
# 404  Senior Scientist, Cell Pharmacology/Assay Deve...    -1.0
# 456  As a Data Scientist, you will play a critical ...    -1.0
# 551  Research Scientist, Immunology - Cancer Biolog...    -1.0
# 581  Scientist – Cancer Discovery, Molecular Assay\...    -1.0
# 609  Senior Scientist, Cell Pharmacology/Assay Deve...    -1.0
# 641  Principal Research Scientist/Team Lead, Medici...    -1.0
#
#                 Company Name           Location       Headquarters  \
# 176        CA-One Tech Cloud  San Francisco, CA        Fremont, CA
# 266        CA-One Tech Cloud  San Francisco, CA        Fremont, CA
# 300                     Muso  San Francisco, CA  San Francisco, CA
# 370               Kronos Bio      Cambridge, MA      San Mateo, CA
# 404               Kronos Bio      Cambridge, MA      San Mateo, CA
# 456                     ALIN       New York, NY       Noida, India
# 551               Kronos Bio      Cambridge, MA      San Mateo, CA
# 581  Monte Rosa Therapeutics      Cambridge, MA                 -1
# 609               Kronos Bio      Cambridge, MA      San Mateo, CA
# 641               Kronos Bio      Cambridge, MA      San Mateo, CA
#
#            Size  Founded  ... tensor hadoop tableau bi flink  mongo  \
# 176   51 - 200      2017  ...      0      0       1  0     0      0
# 266   51 - 200      2017  ...      0      0       1  0     0      0
# 300  201 - 500        -1  ...      0      0       1  0     0      0
# 370     unknown       -1  ...      0      0       0  0     0      0
# 404     unknown       -1  ...      0      0       0  0     0      0
# 456     unknown       -1  ...      1      0       0  0     0      0
# 551     unknown       -1  ...      0      0       0  0     0      0
# 581     unknown       -1  ...      0      0       0  0     0      0
# 609     unknown       -1  ...      0      0       0  0     0      0
# 641     unknown       -1  ...      0      0       0  0     0      0
#
#      google_an    job_title_sim  seniority_by_title  Degree
# 176          0   data scientist                  sr      na
# 266          0   data scientist                  sr      na
# 300          0               na                  sr       M
# 370          0  other scientist                  na       P
# 404          0  other scientist                  sr       P
# 456          0   data scientist                  na       M
# 551          0  other scientist                  na       P
# 581          0  other scientist                  na       P
# 609          0  other scientist                  sr       P
# 641          0  other scientist                  sr       P
#
# [10 rows x 42 columns]
